# %%
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as urReq         

#urllib is used for opening and reading url
#bs is used to beautify the url

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "car"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=car'

# %%
response_website = urReq(flipkart_url)

# %%
data_flipkart = response_website.read()

# %%
beautiful_html = bs(data_flipkart,"html.parser")

# %%
beautiful_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigbox = beautiful_html.find_all("div", {"class" : "_1AtVbE col-12-12"})

# %%
product1 = "https://www.flipkart.com" + bigbox[1].div.div.div.a["href"]

# %%
import requests

#Used for clicking

# %%
product11 = requests.get(product1)

# %%
product1
# Out:
# 'https://www.flipkart.com/spincart-pull-go-monster-car-toy-kids-boys/p/itme7d6c8bf59a51?pid=VPAFMSBFXPU3FVPF&lid=LSTVPAFMSBFXPU3FVPFCA8FMQ&marketplace=FLIPKART&q=car&store=tng%2F56a&srno=s_1_1&otracker=search&fm=organic&iid=d4270ee6-0352-4d58-bb4a-30dc0367a1fc.VPAFMSBFXPU3FVPF.SEARCH&ppt=None&ppn=None&ssid=f6efrpef000000001661767844279&qH=e6d96502596d7e78'

# %%
product11.encoding = 'utf-8'

# %%
product1_page = bs(product11.text, "html.parser")

# %%
all_review = product1_page.find_all("div", {"class":"_16PBlm"})

# %%
len(all_review)
# Out:
# 11

# %%
rating = all_review[1].div.div.div.div.text

# %%
header = all_review[1].div.div.div.p.text

# %%
comment = all_review[1].find_all('div', {"class":""})[0].div.text

# %%
name = all_review[1].find_all('p', {"class": "_2sc7ZR _2V5EHH"})[0].text

# %%
date = all_review[1].find_all('p', {"class" : "_2sc7ZR"})[1].text

# %%
for i in all_review:
    rating = i.div.div.div.div.text
    header = i.div.div.div.p.text
    comment = i.find_all('div', {"class":""})[0].div.text
    name = i.find_all('p', {"class": "_2sc7ZR _2V5EHH"})[0].text
    date = i.find_all('p', {"class" : "_2sc7ZR"})[1].text
    print(f"Customer Name: {name}\nBrief Comment: {header}\nComment: {comment}\nRating: {rating}\nDate: {date}")
    print()
# Out:
# Customer Name: Santhosh Kumar
# Brief Comment: Perfect product!
# Comment: Awesome product 🤩💥
# Rating: 5
# Date: Feb, 2021
#
# Customer Name: Priyanka Pathariya
# Brief Comment: Perfect product!
# Comment: Amazing product ☺️
# Rating: 5
# Date: Apr, 2021
#
# Customer Name: Saumya Singh
# Brief Comment: Value-for-money
# Comment: Nice product
# Rating: 4
# Date: May, 2021
#
# Customer Name: Vikas Sharma
# Brief Comment: Terrific purchase
# Comment: Very good quality.
# Rating: 5
# Date: 7months ago
#
# Customer Name: varinder singh
# Brief Comment: Terrific purchase
# Comment: Very good. Good quality
# Rating: 5
# Date: Jan, 2021
#
# Customer Name: Vivek Palleeri
# Brief Comment: Must buy!
# Comment: The product is small. But quality is good
# Rating: 5
# Date: Apr, 2021
#
# Customer Name: Flipkart Customer
# Brief Comment: Terrific purchase
# Comment: Good product
# Rating: 5
# Date: Jan, 2021
#
# Customer Name: Anil Varma
# Brief Comment: Great product
# ...

# %%
import requests
from bs4 import BeautifulSoup
 
 
# Making a GET request
r = requests.get('https://www.geeksforgeeks.org/python-programming-language/')
 
# Parsing the HTML
soup = BeautifulSoup(r.content, 'html.parser')
 
for i in soup.find_all('img'):
    print(i)
# Out:
# <img alt="Write" src="https://media.geeksforgeeks.org/wp-content/cdn-uploads/write_ndi_20210312.svg"/>
# <img alt="Practice" src="https://media.geeksforgeeks.org/wp-content/cdn-uploads/practice_ndi_20210312.svg"/>
# <img alt="Premium" src="https://media.geeksforgeeks.org/wp-content/cdn-uploads/premium_ndi_20210312.svg"/>
# <img alt="Jobs" src="https://media.geeksforgeeks.org/wp-content/cdn-uploads/jobs_ndi_20210312.svg"/>
# <img alt="python-programming-language Python-Tutorial" class="aligncenter size-full wp-image-430076" src="https://media.geeksforgeeks.org/wp-content/cdn-uploads/20200711122552/Python-Programming-Language.png"/>
# ...
