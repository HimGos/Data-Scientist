# %%
import pandas as pd
import numpy as np

df = pd.read_csv("winequality-red.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# fixed acidity          7.90000   9.200000   15.90000
# volatile acidity       0.52000   0.640000    1.58000
# citric acid            0.26000   0.420000    1.00000
# residual sugar         2.20000   2.600000   15.50000
# chlorides              0.07900   0.090000    0.61100
# free sulfur dioxide   14.00000  21.000000   72.00000
# total sulfur dioxide  38.00000  62.000000  289.00000
# density                0.99675   0.997835    1.00369
# pH                     3.31000   3.400000    4.01000
# sulphates              0.62000   0.730000    2.00000
# alcohol               10.20000  11.100000   14.90000
# quality                6.00000   6.000000    8.00000

# %%
df.duplicated().sum()
# Out:
# 240

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Scaling not required in Decision Tree
#
# Because it doesn't affect

# %%
"""from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit()
scaler.transform()"""
# Out:
# 'from sklearn.preprocessing import StandardScaler\n\nscaler = StandardScaler()\nscaler.fit()\nscaler.transform()'

# %%
from sklearn.model_selection import train_test_split

X = df.drop('quality', axis=1)
y = df['quality']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_train, y_train)
# Out:
# 1.0

# %% [markdown]
# > Model is overfitted

# %%
from sklearn import tree
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(25,15))
tree.plot_tree(model,filled=True)
# Out:
# [Text(0.5013656414907651, 0.9761904761904762, 'X[10] <= 10.15\ngini = 0.652\nsamples = 910\nvalue = [5, 38, 385, 354, 115, 13]'),
#  Text(0.30731571569920846, 0.9285714285714286, 'X[6] <= 91.5\ngini = 0.53\nsamples = 462\nvalue = [4, 24, 288, 129, 15, 2]'),
#  Text(0.15605623350923484, 0.8809523809523809, 'X[1] <= 0.417\ngini = 0.575\nsamples = 377\nvalue = [4, 23, 212, 121, 15, 2]'),
#  Text(0.06754617414248021, 0.8333333333333334, 'X[9] <= 0.655\ngini = 0.622\nsamples = 84\nvalue = [0, 2, 30, 41, 9, 2]'),
#  Text(0.0316622691292876, 0.7857142857142857, 'X[4] <= 0.079\ngini = 0.52\nsamples = 47\nvalue = [0, 1, 24, 22, 0, 0]'),
#  Text(0.016886543535620052, 0.7380952380952381, 'X[5] <= 31.5\ngini = 0.475\nsamples = 18\nvalue = [0, 1, 5, 12, 0, 0]'),
#  Text(0.012664907651715039, 0.6904761904761905, 'X[7] <= 0.996\ngini = 0.398\nsamples = 16\nvalue = [0, 1, 3, 12, 0, 0]'),
#  Text(0.008443271767810026, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.016886543535620052, 0.6428571428571429, 'X[3] <= 2.85\ngini = 0.338\nsamples = 15\nvalue = [0, 1, 2, 12, 0, 0]'),
#  Text(0.012664907651715039, 0.5952380952380952, 'X[9] <= 0.645\ngini = 0.255\nsamples = 14\nvalue = [0, 1, 1, 12, 0, 0]'),
#  Text(0.008443271767810026, 0.5476190476190477, 'X[10] <= 9.95\ngini = 0.142\nsamples = 13\nvalue = [0, 1, 0, 12, 0, 0]'),
#  Text(0.004221635883905013, 0.5, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11, 0, 0]'),
#  Text(0.012664907651715039, 0.5, 'X[1] <= 0.265\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.008443271767810026, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.016886543535620052, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.016886543535620052, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.021108179419525065, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.021108179419525065, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.04643799472295514, 0.7380952380952381, 'X[8] <= 3.37\ngini = 0.452\nsamples = 29\nvalue = [0, 0, 19, 10, 0, 0]'),
#  Text(0.03799472295514512, 0.6904761904761905, 'X[4] <= 0.191\ngini = 0.231\nsamples = 15\nvalue = [0, 0, 13, 2, 0, 0]'),
#  Text(0.033773087071240104, 0.6428571428571429, 'X[10] <= 9.1\ngini = 0.133\nsamples = 14\nvalue = [0, 0, 13, 1, 0, 0]'),
#  Text(0.02955145118733509, 0.5952380952380952, 'X[1] <= 0.36\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.025329815303430078, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.033773087071240104, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.03799472295514512, 0.5952380952380952, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(0.04221635883905013, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.05488126649076517, 0.6904761904761905, 'X[10] <= 9.45\ngini = 0.49\nsamples = 14\nvalue = [0, 0, 6, 8, 0, 0]'),
#  Text(0.050659630606860157, 0.6428571428571429, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.05910290237467018, 0.6428571428571429, 'X[8] <= 3.495\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 8, 0, 0]'),
#  Text(0.05488126649076517, 0.5952380952380952, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.0633245382585752, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.10343007915567283, 0.7857142857142857, 'X[6] <= 31.5\ngini = 0.647\nsamples = 37\nvalue = [0, 1, 6, 19, 9, 2]'),
#  Text(0.08443271767810026, 0.7380952380952381, 'X[5] <= 9.5\ngini = 0.706\nsamples = 17\nvalue = [0, 0, 4, 4, 7, 2]'),
#  Text(0.07176781002638523, 0.6904761904761905, 'X[4] <= 0.073\ngini = 0.691\nsamples = 9\nvalue = [0, 0, 2, 4, 1, 2]'),
#  Text(0.06754617414248021, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.07598944591029023, 0.6428571428571429, 'X[3] <= 1.9\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 2, 4, 1, 0]'),
#  Text(0.07176781002638523, 0.5952380952380952, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.08021108179419525, 0.5952380952380952, 'X[3] <= 2.85\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 0, 1, 0]'),
#  Text(0.07598944591029023, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.08443271767810026, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.0970976253298153, 0.6904761904761905, 'X[7] <= 1.0\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 2, 0, 6, 0]'),
#  Text(0.09287598944591029, 0.6428571428571429, 'X[4] <= 0.062\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 1, 0, 6, 0]'),
#  Text(0.08865435356200528, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.0970976253298153, 0.5952380952380952, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.10131926121372031, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.12242744063324539, 0.7380952380952381, 'X[6] <= 82.5\ngini = 0.415\nsamples = 20\nvalue = [0, 1, 2, 15, 2, 0]'),
#  Text(0.11398416886543536, 0.6904761904761905, 'X[9] <= 1.17\ngini = 0.29\nsamples = 18\nvalue = [0, 0, 1, 15, 2, 0]'),
#  Text(0.10976253298153034, 0.6428571428571429, 'X[8] <= 3.025\ngini = 0.208\nsamples = 17\nvalue = [0, 0, 0, 15, 2, 0]'),
#  Text(0.10554089709762533, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.11398416886543536, 0.5952380952380952, 'X[2] <= 0.37\ngini = 0.117\nsamples = 16\nvalue = [0, 0, 0, 15, 1, 0]'),
#  Text(0.10976253298153034, 0.5476190476190477, 'X[2] <= 0.305\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.10554089709762533, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.11398416886543536, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.11820580474934037, 0.5476190476190477, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.11820580474934037, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.1308707124010554, 0.6904761904761905, 'X[0] <= 8.6\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.1266490765171504, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.13509234828496042, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.24456629287598944, 0.8333333333333334, 'X[9] <= 0.535\ngini = 0.534\nsamples = 293\nvalue = [4, 21, 182, 80, 6, 0]'),
#  Text(0.158311345646438, 0.7857142857142857, 'X[10] <= 9.05\ngini = 0.456\nsamples = 80\nvalue = [1, 13, 57, 8, 1, 0]'),
#  Text(0.15408970976253297, 0.7380952380952381, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.162532981530343, 0.7380952380952381, 'X[1] <= 0.877\ngini = 0.435\nsamples = 78\nvalue = [1, 11, 57, 8, 1, 0]'),
#  Text(0.15197889182058047, 0.6904761904761905, 'X[3] <= 1.25\ngini = 0.399\nsamples = 71\nvalue = [1, 7, 54, 8, 1, 0]'),
#  Text(0.14353562005277046, 0.6428571428571429, 'X[4] <= 0.166\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 1, 0]'),
#  Text(0.13931398416886542, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.14775725593667546, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.1604221635883905, 0.6428571428571429, 'X[7] <= 0.996\ngini = 0.364\nsamples = 69\nvalue = [0, 7, 54, 8, 0, 0]'),
#  Text(0.15620052770448548, 0.5952380952380952, 'gini = 0.0\nsamples = 23\nvalue = [0, 0, 23, 0, 0, 0]'),
#  Text(0.16464379947229552, 0.5952380952380952, 'X[4] <= 0.08\ngini = 0.492\nsamples = 46\nvalue = [0, 7, 31, 8, 0, 0]'),
#  Text(0.14986807387862797, 0.5476190476190477, 'X[10] <= 9.35\ngini = 0.498\nsamples = 15\nvalue = [0, 0, 8, 7, 0, 0]'),
#  Text(0.14564643799472296, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.15408970976253297, 0.5, 'X[2] <= 0.105\ngini = 0.42\nsamples = 10\nvalue = [0, 0, 3, 7, 0, 0]'),
#  Text(0.14564643799472296, 0.4523809523809524, 'X[3] <= 1.8\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.14142480211081795, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.14986807387862797, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.162532981530343, 0.4523809523809524, 'X[1] <= 0.772\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 1, 6, 0, 0]'),
#  Text(0.158311345646438, 0.40476190476190477, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.16675461741424802, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.17941952506596306, 0.5476190476190477, 'X[8] <= 3.255\ngini = 0.398\nsamples = 31\nvalue = [0, 7, 23, 1, 0, 0]'),
#  Text(0.17519788918205806, 0.5, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.18364116094986807, 0.5, 'X[8] <= 3.385\ngini = 0.492\nsamples = 22\nvalue = [0, 7, 14, 1, 0, 0]'),
#  Text(0.17941952506596306, 0.4523809523809524, 'X[7] <= 0.998\ngini = 0.56\nsamples = 15\nvalue = [0, 7, 7, 1, 0, 0]'),
#  Text(0.17519788918205806, 0.40476190476190477, 'X[7] <= 0.998\ngini = 0.512\nsamples = 11\nvalue = [0, 7, 3, 1, 0, 0]'),
#  Text(0.17097625329815302, 0.35714285714285715, 'X[10] <= 9.55\ngini = 0.611\nsamples = 6\nvalue = [0, 2, 3, 1, 0, 0]'),
#  Text(0.16675461741424802, 0.30952380952380953, 'X[8] <= 3.365\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.162532981530343, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.17097625329815302, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.17519788918205806, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.17941952506596306, 0.35714285714285715, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0, 0, 0]'),
#  Text(0.18364116094986807, 0.40476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.18786279683377308, 0.4523809523809524, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.17308707124010553, 0.6904761904761905, 'X[1] <= 0.96\ngini = 0.49\nsamples = 7\nvalue = [0, 4, 3, 0, 0, 0]'),
#  Text(0.16886543535620052, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.17730870712401056, 0.6428571428571429, 'X[7] <= 0.995\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3, 0, 0, 0]'),
#  Text(0.17308707124010553, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.18153034300791557, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.33082124010554087, 0.7857142857142857, 'X[7] <= 0.998\ngini = 0.539\nsamples = 213\nvalue = [3, 8, 125, 72, 5, 0]'),
#  Text(0.26982189973614773, 0.7380952380952381, 'X[7] <= 0.995\ngini = 0.477\nsamples = 151\nvalue = [1, 3, 99, 46, 2, 0]'),
#  Text(0.2505277044854881, 0.6904761904761905, 'X[4] <= 0.078\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 0, 4, 0, 0]'),
#  Text(0.2463060686015831, 0.6428571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.2547493403693931, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.2891160949868074, 0.6904761904761905, 'X[1] <= 0.652\ngini = 0.457\nsamples = 146\nvalue = [1, 2, 99, 42, 2, 0]'),
#  Text(0.2631926121372032, 0.6428571428571429, 'X[7] <= 0.997\ngini = 0.494\nsamples = 89\nvalue = [0, 0, 54, 33, 2, 0]'),
#  Text(0.24089709762532982, 0.5952380952380952, 'X[2] <= 0.045\ngini = 0.471\nsamples = 80\nvalue = [0, 0, 52, 26, 2, 0]'),
#  Text(0.20897097625329816, 0.5476190476190477, 'X[5] <= 17.5\ngini = 0.537\nsamples = 18\nvalue = [0, 0, 7, 10, 1, 0]'),
#  Text(0.20474934036939313, 0.5, 'X[0] <= 6.8\ngini = 0.439\nsamples = 14\nvalue = [0, 0, 3, 10, 1, 0]'),
#  Text(0.19630606860158312, 0.4523809523809524, 'X[6] <= 15.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.1920844327176781, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.20052770448548812, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.21319261213720317, 0.4523809523809524, 'X[7] <= 0.996\ngini = 0.314\nsamples = 11\nvalue = [0, 0, 1, 9, 1, 0]'),
#  Text(0.20897097625329816, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.21741424802110818, 0.40476190476190477, 'X[9] <= 0.575\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 0, 9, 1, 0]'),
#  Text(0.21319261213720317, 0.35714285714285715, 'X[4] <= 0.074\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.20897097625329816, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.21741424802110818, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.22163588390501318, 0.35714285714285715, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.21319261213720317, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.2728232189973615, 0.5476190476190477, 'X[7] <= 0.997\ngini = 0.406\nsamples = 62\nvalue = [0, 0, 45, 16, 1, 0]'),
#  Text(0.26860158311345644, 0.5, 'X[7] <= 0.997\ngini = 0.452\nsamples = 52\nvalue = [0, 0, 35, 16, 1, 0]'),
#  Text(0.25646437994722954, 0.4523809523809524, 'X[6] <= 73.5\ngini = 0.395\nsamples = 48\nvalue = [0, 0, 35, 13, 0, 0]'),
#  Text(0.24485488126649077, 0.40476190476190477, 'X[10] <= 10.017\ngini = 0.343\nsamples = 41\nvalue = [0, 0, 32, 9, 0, 0]'),
#  Text(0.23430079155672823, 0.35714285714285715, 'X[4] <= 0.066\ngini = 0.301\nsamples = 38\nvalue = [0, 0, 31, 7, 0, 0]'),
#  Text(0.22585751978891822, 0.30952380952380953, 'X[7] <= 0.996\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.22163588390501318, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.23007915567282322, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.24274406332453827, 0.30952380952380953, 'X[2] <= 0.635\ngini = 0.245\nsamples = 35\nvalue = [0, 0, 30, 5, 0, 0]'),
#  Text(0.23852242744063323, 0.2619047619047619, 'X[8] <= 3.49\ngini = 0.208\nsamples = 34\nvalue = [0, 0, 30, 4, 0, 0]'),
#  Text(0.23007915567282322, 0.21428571428571427, 'X[4] <= 0.089\ngini = 0.124\nsamples = 30\nvalue = [0, 0, 28, 2, 0, 0]'),
#  Text(0.22585751978891822, 0.16666666666666666, 'gini = 0.0\nsamples = 18\nvalue = [0, 0, 18, 0, 0, 0]'),
#  Text(0.23430079155672823, 0.16666666666666666, 'X[8] <= 3.32\ngini = 0.278\nsamples = 12\nvalue = [0, 0, 10, 2, 0, 0]'),
#  Text(0.23007915567282322, 0.11904761904761904, 'X[3] <= 2.35\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 10, 1, 0, 0]'),
#  Text(0.22585751978891822, 0.07142857142857142, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.23430079155672823, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.23852242744063323, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.24696569920844327, 0.21428571428571427, 'X[8] <= 3.53\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.24274406332453827, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2511873350923483, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.24696569920844327, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2554089709762533, 0.35714285714285715, 'X[4] <= 0.078\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.2511873350923483, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2596306068601583, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.26807387862796833, 0.40476190476190477, 'X[6] <= 83.0\ngini = 0.49\nsamples = 7\nvalue = [0, 0, 3, 4, 0, 0]'),
#  Text(0.2638522427440633, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.27229551451187334, 0.35714285714285715, 'X[9] <= 0.57\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.26807387862796833, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.27651715039577834, 0.30952380952380953, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.28073878627968335, 0.4523809523809524, 'X[2] <= 0.25\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.27651715039577834, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.2849604221635884, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2770448548812665, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.2854881266490765, 0.5952380952380952, 'X[0] <= 8.85\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 2, 7, 0, 0]'),
#  Text(0.2812664907651715, 0.5476190476190477, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.28970976253298153, 0.5476190476190477, 'X[2] <= 0.24\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.2854881266490765, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.29393139841688654, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3150395778364116, 0.6428571428571429, 'X[1] <= 0.943\ngini = 0.35\nsamples = 57\nvalue = [1, 2, 45, 9, 0, 0]'),
#  Text(0.3065963060686016, 0.5952380952380952, 'X[3] <= 1.35\ngini = 0.309\nsamples = 55\nvalue = [1, 1, 45, 8, 0, 0]'),
#  Text(0.30237467018469655, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.3108179419525066, 0.5476190476190477, 'X[2] <= 0.075\ngini = 0.283\nsamples = 54\nvalue = [1, 0, 45, 8, 0, 0]'),
#  Text(0.30237467018469655, 0.5, 'X[6] <= 12.5\ngini = 0.077\nsamples = 25\nvalue = [1, 0, 24, 0, 0, 0]'),
#  Text(0.29815303430079154, 0.4523809523809524, 'X[4] <= 0.079\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0, 0, 0]'),
#  Text(0.29393139841688654, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.30237467018469655, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3065963060686016, 0.4523809523809524, 'gini = 0.0\nsamples = 23\nvalue = [0, 0, 23, 0, 0, 0]'),
#  Text(0.31926121372031663, 0.5, 'X[2] <= 0.09\ngini = 0.4\nsamples = 29\nvalue = [0, 0, 21, 8, 0, 0]'),
#  Text(0.3150395778364116, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.32348284960422163, 0.4523809523809524, 'X[2] <= 0.615\ngini = 0.346\nsamples = 27\nvalue = [0, 0, 21, 6, 0, 0]'),
#  Text(0.31926121372031663, 0.40476190476190477, 'X[5] <= 3.5\ngini = 0.311\nsamples = 26\nvalue = [0, 0, 21, 5, 0, 0]'),
#  Text(0.3150395778364116, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.32348284960422163, 0.35714285714285715, 'X[9] <= 0.6\ngini = 0.269\nsamples = 25\nvalue = [0, 0, 21, 4, 0, 0]'),
#  Text(0.31926121372031663, 0.30952380952380953, 'X[6] <= 41.5\ngini = 0.444\nsamples = 12\nvalue = [0, 0, 8, 4, 0, 0]'),
#  Text(0.3150395778364116, 0.2619047619047619, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.32348284960422163, 0.2619047619047619, 'X[1] <= 0.76\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 4, 4, 0, 0]'),
#  Text(0.31926121372031663, 0.21428571428571427, 'X[4] <= 0.074\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.3150395778364116, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.32348284960422163, 0.16666666666666666, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.32770448548812664, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.32770448548812664, 0.30952380952380953, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]'),
#  Text(0.32770448548812664, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.32348284960422163, 0.5952380952380952, 'X[10] <= 9.65\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.31926121372031663, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.32770448548812664, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.391820580474934, 0.7380952380952381, 'X[9] <= 0.695\ngini = 0.638\nsamples = 62\nvalue = [2, 5, 26, 26, 3, 0]'),
#  Text(0.36728232189973614, 0.6904761904761905, 'X[5] <= 15.0\ngini = 0.609\nsamples = 42\nvalue = [2, 3, 23, 12, 2, 0]'),
#  Text(0.35197889182058045, 0.6428571428571429, 'X[2] <= 0.135\ngini = 0.685\nsamples = 25\nvalue = [2, 2, 8, 11, 2, 0]'),
#  Text(0.3403693931398417, 0.5952380952380952, 'X[3] <= 1.85\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 0, 5, 0, 0]'),
#  Text(0.33614775725593665, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.3445910290237467, 0.5476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.36358839050131925, 0.5952380952380952, 'X[6] <= 18.5\ngini = 0.698\nsamples = 19\nvalue = [2, 1, 8, 6, 2, 0]'),
#  Text(0.35303430079155673, 0.5476190476190477, 'X[10] <= 8.7\ngini = 0.32\nsamples = 5\nvalue = [1, 0, 0, 4, 0, 0]'),
#  Text(0.3488126649076517, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.35725593667546174, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.3741424802110818, 0.5476190476190477, 'X[1] <= 0.53\ngini = 0.622\nsamples = 14\nvalue = [1, 1, 8, 2, 2, 0]'),
#  Text(0.36569920844327175, 0.5, 'X[6] <= 41.5\ngini = 0.64\nsamples = 5\nvalue = [0, 0, 1, 2, 2, 0]'),
#  Text(0.36147757255936674, 0.4523809523809524, 'X[8] <= 3.165\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.35725593667546174, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.36569920844327175, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.36992084432717676, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.38258575197889183, 0.5, 'X[3] <= 2.25\ngini = 0.37\nsamples = 9\nvalue = [1, 1, 7, 0, 0, 0]'),
#  Text(0.3783641160949868, 0.4523809523809524, 'X[1] <= 0.585\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0, 0]'),
#  Text(0.3741424802110818, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.38258575197889183, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.38680738786279684, 0.4523809523809524, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.38258575197889183, 0.6428571428571429, 'X[0] <= 10.5\ngini = 0.215\nsamples = 17\nvalue = [0, 1, 15, 1, 0, 0]'),
#  Text(0.3783641160949868, 0.5952380952380952, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0, 0, 0]'),
#  Text(0.38680738786279684, 0.5952380952380952, 'X[10] <= 9.85\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.38258575197889183, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.39102902374670184, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.41635883905013193, 0.6904761904761905, 'X[4] <= 0.095\ngini = 0.475\nsamples = 20\nvalue = [0, 2, 3, 14, 1, 0]'),
#  Text(0.4079155672823219, 0.6428571428571429, 'X[3] <= 4.95\ngini = 0.381\nsamples = 17\nvalue = [0, 0, 3, 13, 1, 0]'),
#  Text(0.40369393139841686, 0.5952380952380952, 'X[8] <= 3.415\ngini = 0.305\nsamples = 16\nvalue = [0, 0, 3, 13, 0, 0]'),
#  Text(0.39947229551451185, 0.5476190476190477, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.4079155672823219, 0.5476190476190477, 'X[4] <= 0.08\ngini = 0.469\nsamples = 8\nvalue = [0, 0, 3, 5, 0, 0]'),
#  Text(0.40369393139841686, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.41213720316622693, 0.5, 'X[5] <= 7.0\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.4079155672823219, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.41635883905013193, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.41213720316622693, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.42480211081794195, 0.6428571428571429, 'X[9] <= 0.92\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 1, 0, 0]'),
#  Text(0.42058047493403694, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.42902374670184695, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.45857519788918205, 0.8809523809523809, 'X[2] <= 0.315\ngini = 0.192\nsamples = 85\nvalue = [0, 1, 76, 8, 0, 0]'),
#  Text(0.45435356200527705, 0.8333333333333334, 'X[8] <= 3.225\ngini = 0.302\nsamples = 50\nvalue = [0, 1, 41, 8, 0, 0]'),
#  Text(0.44591029023746703, 0.7857142857142857, 'X[7] <= 0.997\ngini = 0.539\nsamples = 16\nvalue = [0, 1, 9, 6, 0, 0]'),
#  Text(0.441688654353562, 0.7380952380952381, 'X[0] <= 8.15\ngini = 0.494\nsamples = 9\nvalue = [0, 1, 2, 6, 0, 0]'),
#  Text(0.43746701846965697, 0.6904761904761905, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.44591029023746703, 0.6904761904761905, 'X[3] <= 1.95\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 2, 1, 0, 0]'),
#  Text(0.441688654353562, 0.6428571428571429, 'X[5] <= 23.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.43746701846965697, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.44591029023746703, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.45013192612137204, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.45013192612137204, 0.7380952380952381, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.46279683377308706, 0.7857142857142857, 'X[1] <= 0.535\ngini = 0.111\nsamples = 34\nvalue = [0, 0, 32, 2, 0, 0]'),
#  Text(0.45857519788918205, 0.7380952380952381, 'X[5] <= 20.0\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 8, 2, 0, 0]'),
#  Text(0.45435356200527705, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.46279683377308706, 0.6904761904761905, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.46701846965699206, 0.7380952380952381, 'gini = 0.0\nsamples = 24\nvalue = [0, 0, 24, 0, 0, 0]'),
#  Text(0.46279683377308706, 0.8333333333333334, 'gini = 0.0\nsamples = 35\nvalue = [0, 0, 35, 0, 0, 0]'),
#  Text(0.6954155672823219, 0.9285714285714286, 'X[1] <= 0.375\ngini = 0.649\nsamples = 448\nvalue = [1, 14, 97, 225, 100, 11]'),
#  Text(0.524967018469657, 0.8809523809523809, 'X[9] <= 0.565\ngini = 0.656\nsamples = 127\nvalue = [0, 0, 20, 48, 53, 6]'),
#  Text(0.48390501319261214, 0.8333333333333334, 'X[7] <= 0.995\ngini = 0.459\nsamples = 22\nvalue = [0, 0, 1, 15, 6, 0]'),
#  Text(0.47968337730870714, 0.7857142857142857, 'X[1] <= 0.25\ngini = 0.569\nsamples = 12\nvalue = [0, 0, 1, 5, 6, 0]'),
#  Text(0.47546174142480213, 0.7380952380952381, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.48390501319261214, 0.7380952380952381, 'X[8] <= 3.28\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 1, 2, 6, 0]'),
#  Text(0.47546174142480213, 0.6904761904761905, 'X[8] <= 3.185\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 0, 5, 0]'),
#  Text(0.4712401055408971, 0.6428571428571429, 'X[4] <= 0.054\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.46701846965699206, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.47546174142480213, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.47968337730870714, 0.6428571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.49234828496042216, 0.6904761904761905, 'X[10] <= 12.7\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.48812664907651715, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.49656992084432716, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.48812664907651715, 0.7857142857142857, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.5660290237467018, 0.8333333333333334, 'X[9] <= 0.705\ngini = 0.665\nsamples = 105\nvalue = [0, 0, 19, 33, 47, 6]'),
#  Text(0.5197889182058048, 0.7857142857142857, 'X[10] <= 11.15\ngini = 0.699\nsamples = 34\nvalue = [0, 0, 13, 7, 11, 3]'),
#  Text(0.5050131926121372, 0.7380952380952381, 'X[2] <= 0.385\ngini = 0.48\nsamples = 15\nvalue = [0, 0, 10, 0, 4, 1]'),
#  Text(0.5007915567282322, 0.6904761904761905, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.5092348284960422, 0.6904761904761905, 'X[0] <= 11.5\ngini = 0.292\nsamples = 12\nvalue = [0, 0, 10, 0, 1, 1]'),
#  Text(0.5050131926121372, 0.6428571428571429, 'X[0] <= 10.45\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 10, 0, 0, 1]'),
#  Text(0.5007915567282322, 0.5952380952380952, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.5092348284960422, 0.5952380952380952, 'X[6] <= 31.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1]'),
#  Text(0.5050131926121372, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.5134564643799472, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5134564643799472, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5345646437994723, 0.7380952380952381, 'X[10] <= 12.0\ngini = 0.693\nsamples = 19\nvalue = [0, 0, 3, 7, 7, 2]'),
#  Text(0.5303430079155673, 0.6904761904761905, 'X[7] <= 0.995\ngini = 0.684\nsamples = 15\nvalue = [0, 0, 3, 7, 3, 2]'),
#  Text(0.5218997361477573, 0.6428571428571429, 'X[3] <= 1.75\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 0, 1, 2]'),
#  Text(0.5176781002638522, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5261213720316623, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.5387862796833773, 0.6428571428571429, 'X[4] <= 0.086\ngini = 0.569\nsamples = 12\nvalue = [0, 0, 3, 7, 2, 0]'),
#  Text(0.5345646437994723, 0.5952380952380952, 'X[10] <= 11.85\ngini = 0.656\nsamples = 8\nvalue = [0, 0, 3, 3, 2, 0]'),
#  Text(0.5303430079155673, 0.5476190476190477, 'X[5] <= 8.0\ngini = 0.611\nsamples = 6\nvalue = [0, 0, 3, 1, 2, 0]'),
#  Text(0.5218997361477573, 0.5, 'X[10] <= 11.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.5176781002638522, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5261213720316623, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5387862796833773, 0.5, 'X[8] <= 3.11\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 0, 1, 0]'),
#  Text(0.5345646437994723, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5430079155672823, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.5387862796833773, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5430079155672823, 0.5952380952380952, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.5387862796833773, 0.6904761904761905, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.6122691292875989, 0.7857142857142857, 'X[5] <= 21.5\ngini = 0.6\nsamples = 71\nvalue = [0, 0, 6, 26, 36, 3]'),
#  Text(0.5759894459102902, 0.7380952380952381, 'X[7] <= 0.995\ngini = 0.544\nsamples = 48\nvalue = [0, 0, 2, 14, 29, 3]'),
#  Text(0.5598944591029024, 0.6904761904761905, 'X[6] <= 56.5\ngini = 0.266\nsamples = 19\nvalue = [0, 0, 0, 3, 16, 0]'),
#  Text(0.5556728232189974, 0.6428571428571429, 'X[9] <= 0.915\ngini = 0.111\nsamples = 17\nvalue = [0, 0, 0, 1, 16, 0]'),
#  Text(0.5514511873350924, 0.5952380952380952, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 0, 0, 16, 0]'),
#  Text(0.5598944591029024, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5641160949868074, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5920844327176781, 0.6904761904761905, 'X[4] <= 0.082\ngini = 0.64\nsamples = 29\nvalue = [0, 0, 2, 11, 13, 3]'),
#  Text(0.5799472295514512, 0.6428571428571429, 'X[3] <= 2.7\ngini = 0.635\nsamples = 20\nvalue = [0, 0, 1, 10, 6, 3]'),
#  Text(0.5683377308707124, 0.5952380952380952, 'X[10] <= 10.55\ngini = 0.539\nsamples = 16\nvalue = [0, 0, 1, 9, 6, 0]'),
#  Text(0.5577836411609499, 0.5476190476190477, 'X[1] <= 0.285\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 3, 0]'),
#  Text(0.5535620052770448, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5620052770448549, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.578891820580475, 0.5476190476190477, 'X[1] <= 0.265\ngini = 0.486\nsamples = 12\nvalue = [0, 0, 1, 8, 3, 0]'),
#  Text(0.5704485488126649, 0.5, 'X[9] <= 1.055\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 3, 0]'),
#  Text(0.5662269129287599, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.5746701846965699, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.587335092348285, 0.5, 'X[6] <= 14.5\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]'),
#  Text(0.58311345646438, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.59155672823219, 0.4523809523809524, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.59155672823219, 0.5952380952380952, 'X[10] <= 11.3\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 0, 3]'),
#  Text(0.587335092348285, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.595778364116095, 0.5476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3]'),
#  Text(0.604221635883905, 0.6428571428571429, 'X[4] <= 0.152\ngini = 0.37\nsamples = 9\nvalue = [0, 0, 1, 1, 7, 0]'),
#  Text(0.6, 0.5952380952380952, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.60844327176781, 0.5952380952380952, 'X[5] <= 10.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.604221635883905, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.612664907651715, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6485488126649076, 0.7380952380952381, 'X[6] <= 65.0\ngini = 0.605\nsamples = 23\nvalue = [0, 0, 4, 12, 7, 0]'),
#  Text(0.6379947229551451, 0.6904761904761905, 'X[5] <= 28.5\ngini = 0.338\nsamples = 15\nvalue = [0, 0, 1, 12, 2, 0]'),
#  Text(0.6295514511873351, 0.6428571428571429, 'X[2] <= 0.285\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 1, 10, 0, 0]'),
#  Text(0.6253298153034301, 0.5952380952380952, 'X[10] <= 12.3\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.6211081794195251, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6295514511873351, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6337730870712401, 0.5952380952380952, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.6464379947229552, 0.6428571428571429, 'X[4] <= 0.075\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 0, 2, 2, 0]'),
#  Text(0.6422163588390501, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.6506596306068602, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.6591029023746702, 0.6904761904761905, 'X[1] <= 0.335\ngini = 0.469\nsamples = 8\nvalue = [0, 0, 3, 0, 5, 0]'),
#  Text(0.6548812664907652, 0.6428571428571429, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.6633245382585752, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.8658641160949868, 0.8809523809523809, 'X[10] <= 11.45\ngini = 0.615\nsamples = 321\nvalue = [1, 14, 77, 177, 47, 5]'),
#  Text(0.8103562005277045, 0.8333333333333334, 'X[1] <= 0.923\ngini = 0.582\nsamples = 211\nvalue = [1, 11, 64, 119, 15, 1]'),
#  Text(0.7853562005277045, 0.7857142857142857, 'X[7] <= 1.0\ngini = 0.561\nsamples = 204\nvalue = [0, 7, 62, 119, 15, 1]'),
#  Text(0.7480211081794196, 0.7380952380952381, 'X[9] <= 0.575\ngini = 0.544\nsamples = 194\nvalue = [0, 7, 55, 118, 13, 1]'),
#  Text(0.6944591029023747, 0.6904761904761905, 'X[6] <= 13.5\ngini = 0.616\nsamples = 51\nvalue = [0, 5, 21, 23, 2, 0]'),
#  Text(0.6717678100263852, 0.6428571428571429, 'X[2] <= 0.355\ngini = 0.46\nsamples = 10\nvalue = [0, 2, 7, 1, 0, 0]'),
#  Text(0.6633245382585752, 0.5952380952380952, 'X[6] <= 10.0\ngini = 0.219\nsamples = 8\nvalue = [0, 1, 7, 0, 0, 0]'),
#  Text(0.6591029023746702, 0.5476190476190477, 'X[0] <= 7.25\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.6548812664907652, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6633245382585752, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.6675461741424802, 0.5476190476190477, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.6802110817941952, 0.5952380952380952, 'X[6] <= 10.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.6759894459102902, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.6844327176781002, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7171503957783641, 0.6428571428571429, 'X[3] <= 2.25\ngini = 0.588\nsamples = 41\nvalue = [0, 3, 14, 22, 2, 0]'),
#  Text(0.6970976253298153, 0.5952380952380952, 'X[2] <= 0.015\ngini = 0.394\nsamples = 17\nvalue = [0, 1, 2, 13, 1, 0]'),
#  Text(0.6928759894459103, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7013192612137203, 0.5476190476190477, 'X[8] <= 3.52\ngini = 0.32\nsamples = 16\nvalue = [0, 1, 2, 13, 0, 0]'),
#  Text(0.6970976253298153, 0.5, 'X[6] <= 44.5\ngini = 0.24\nsamples = 15\nvalue = [0, 1, 1, 13, 0, 0]'),
#  Text(0.6928759894459103, 0.4523809523809524, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.7013192612137203, 0.4523809523809524, 'X[4] <= 0.065\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 1, 3, 0, 0]'),
#  Text(0.6970976253298153, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.7055408970976254, 0.40476190476190477, 'X[9] <= 0.555\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.7013192612137203, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7097625329815304, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.7055408970976254, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.737203166226913, 0.5952380952380952, 'X[3] <= 3.3\ngini = 0.601\nsamples = 24\nvalue = [0, 2, 12, 9, 1, 0]'),
#  Text(0.7224274406332454, 0.5476190476190477, 'X[2] <= 0.015\ngini = 0.444\nsamples = 18\nvalue = [0, 0, 12, 6, 0, 0]'),
#  Text(0.7139841688654354, 0.5, 'X[9] <= 0.525\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.7097625329815304, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7182058047493404, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.7308707124010554, 0.5, 'X[10] <= 10.35\ngini = 0.26\nsamples = 13\nvalue = [0, 0, 11, 2, 0, 0]'),
#  Text(0.7266490765171504, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7350923482849604, 0.4523809523809524, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.7519788918205804, 0.5476190476190477, 'X[8] <= 3.38\ngini = 0.611\nsamples = 6\nvalue = [0, 2, 0, 3, 1, 0]'),
#  Text(0.7477572559366754, 0.5, 'X[4] <= 0.065\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.7435356200527704, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7519788918205804, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.7562005277044855, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.8015831134564644, 0.6904761904761905, 'X[6] <= 86.0\ngini = 0.496\nsamples = 143\nvalue = [0, 2, 34, 95, 11, 1]'),
#  Text(0.7973614775725594, 0.6428571428571429, 'X[8] <= 3.445\ngini = 0.475\nsamples = 138\nvalue = [0, 2, 29, 95, 11, 1]'),
#  Text(0.7773087071240106, 0.5952380952380952, 'X[8] <= 3.025\ngini = 0.428\nsamples = 116\nvalue = [0, 2, 20, 85, 8, 1]'),
#  Text(0.7688654353562006, 0.5476190476190477, 'X[2] <= 0.445\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 0, 1, 0]'),
#  Text(0.7646437994722955, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.7730870712401056, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7857519788918206, 0.5476190476190477, 'X[9] <= 1.18\ngini = 0.405\nsamples = 113\nvalue = [0, 2, 18, 85, 7, 1]'),
#  Text(0.7815303430079156, 0.5, 'X[2] <= 0.715\ngini = 0.397\nsamples = 112\nvalue = [0, 2, 17, 85, 7, 1]'),
#  Text(0.7773087071240106, 0.4523809523809524, 'X[6] <= 6.5\ngini = 0.388\nsamples = 111\nvalue = [0, 2, 16, 85, 7, 1]'),
#  Text(0.7730870712401056, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7815303430079156, 0.40476190476190477, 'X[4] <= 0.068\ngini = 0.38\nsamples = 110\nvalue = [0, 2, 15, 85, 7, 1]'),
#  Text(0.7406332453825858, 0.35714285714285715, 'X[4] <= 0.065\ngini = 0.548\nsamples = 19\nvalue = [0, 1, 1, 12, 4, 1]'),
#  Text(0.7321899736147758, 0.30952380952380953, 'X[9] <= 0.595\ngini = 0.367\nsamples = 14\nvalue = [0, 0, 1, 11, 1, 1]'),
#  Text(0.7279683377308707, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7364116094986808, 0.2619047619047619, 'X[10] <= 11.15\ngini = 0.272\nsamples = 13\nvalue = [0, 0, 1, 11, 0, 1]'),
#  Text(0.7321899736147758, 0.21428571428571427, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.7406332453825858, 0.21428571428571427, 'X[2] <= 0.18\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 1, 1, 0, 1]'),
#  Text(0.7364116094986808, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7448548812664908, 0.16666666666666666, 'X[2] <= 0.29\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1]'),
#  Text(0.7406332453825858, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7490765171503958, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.7490765171503958, 0.30952380952380953, 'X[6] <= 15.0\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 0, 1, 3, 0]'),
#  Text(0.7448548812664908, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.7532981530343008, 0.2619047619047619, 'X[7] <= 0.997\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 3, 0]'),
#  Text(0.7490765171503958, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.7575197889182058, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8224274406332454, 0.35714285714285715, 'X[9] <= 0.74\ngini = 0.332\nsamples = 91\nvalue = [0, 1, 14, 73, 3, 0]'),
#  Text(0.7944591029023746, 0.30952380952380953, 'X[2] <= 0.235\ngini = 0.372\nsamples = 68\nvalue = [0, 1, 14, 52, 1, 0]'),
#  Text(0.7744063324538258, 0.2619047619047619, 'X[1] <= 0.695\ngini = 0.245\nsamples = 36\nvalue = [0, 0, 4, 31, 1, 0]'),
#  Text(0.7659630606860158, 0.21428571428571427, 'X[3] <= 2.1\ngini = 0.135\nsamples = 28\nvalue = [0, 0, 1, 26, 1, 0]'),
#  Text(0.7617414248021108, 0.16666666666666666, 'X[10] <= 10.35\ngini = 0.406\nsamples = 8\nvalue = [0, 0, 1, 6, 1, 0]'),
#  Text(0.7575197889182058, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7659630606860158, 0.11904761904761904, 'X[6] <= 17.5\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 6, 1, 0]'),
#  Text(0.7617414248021108, 0.07142857142857142, 'X[3] <= 1.9\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.7575197889182058, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7659630606860158, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7701846965699208, 0.07142857142857142, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.7701846965699208, 0.16666666666666666, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 0, 20, 0, 0]'),
#  Text(0.7828496042216359, 0.21428571428571427, 'X[1] <= 0.757\ngini = 0.469\nsamples = 8\nvalue = [0, 0, 3, 5, 0, 0]'),
#  Text(0.7786279683377308, 0.16666666666666666, 'X[3] <= 2.65\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.7744063324538258, 0.11904761904761904, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.7828496042216359, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7870712401055409, 0.16666666666666666, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.8145118733509235, 0.2619047619047619, 'X[0] <= 7.9\ngini = 0.471\nsamples = 32\nvalue = [0, 1, 10, 21, 0, 0]'),
#  Text(0.799736147757256, 0.21428571428571427, 'X[10] <= 11.3\ngini = 0.531\nsamples = 8\nvalue = [0, 1, 5, 2, 0, 0]'),
#  Text(0.7955145118733509, 0.16666666666666666, 'X[6] <= 62.0\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]'),
#  Text(0.7912928759894459, 0.11904761904761904, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.799736147757256, 0.11904761904761904, 'X[9] <= 0.705\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.7955145118733509, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.803957783641161, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.803957783641161, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.829287598944591, 0.21428571428571427, 'X[4] <= 0.098\ngini = 0.33\nsamples = 24\nvalue = [0, 0, 5, 19, 0, 0]'),
#  Text(0.820844327176781, 0.16666666666666666, 'X[9] <= 0.725\ngini = 0.18\nsamples = 20\nvalue = [0, 0, 2, 18, 0, 0]'),
#  Text(0.816622691292876, 0.11904761904761904, 'X[5] <= 5.5\ngini = 0.1\nsamples = 19\nvalue = [0, 0, 1, 18, 0, 0]'),
#  Text(0.812401055408971, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.820844327176781, 0.07142857142857142, 'gini = 0.0\nsamples = 18\nvalue = [0, 0, 0, 18, 0, 0]'),
#  Text(0.825065963060686, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.837730870712401, 0.16666666666666666, 'X[9] <= 0.715\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.833509234828496, 0.11904761904761904, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.841952506596306, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8503957783641161, 0.30952380952380953, 'X[4] <= 0.071\ngini = 0.159\nsamples = 23\nvalue = [0, 0, 0, 21, 2, 0]'),
#  Text(0.841952506596306, 0.2619047619047619, 'X[8] <= 3.145\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.837730870712401, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8461741424802111, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8588390501319261, 0.2619047619047619, 'X[2] <= 0.11\ngini = 0.095\nsamples = 20\nvalue = [0, 0, 0, 19, 1, 0]'),
#  Text(0.8546174142480211, 0.21428571428571427, 'X[2] <= 0.07\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.8503957783641161, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8588390501319261, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8630606860158311, 0.21428571428571427, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 0, 16, 0, 0]'),
#  Text(0.7857519788918206, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7899736147757256, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8174142480211082, 0.5952380952380952, 'X[10] <= 10.65\ngini = 0.607\nsamples = 22\nvalue = [0, 0, 9, 10, 3, 0]'),
#  Text(0.8026385224274406, 0.5476190476190477, 'X[1] <= 0.485\ngini = 0.43\nsamples = 11\nvalue = [0, 0, 8, 2, 1, 0]'),
#  Text(0.7984168865435356, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8068601583113456, 0.5, 'X[4] <= 0.082\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 8, 0, 1, 0]'),
#  Text(0.8026385224274406, 0.4523809523809524, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.8110817941952506, 0.4523809523809524, 'X[7] <= 0.996\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.8068601583113456, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8153034300791556, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8321899736147758, 0.5476190476190477, 'X[7] <= 0.994\ngini = 0.43\nsamples = 11\nvalue = [0, 0, 1, 8, 2, 0]'),
#  Text(0.8237467018469657, 0.5, 'X[7] <= 0.994\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.8195250659630607, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8279683377308708, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8406332453825858, 0.5, 'X[4] <= 0.079\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 0, 8, 1, 0]'),
#  Text(0.8364116094986808, 0.4523809523809524, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.8448548812664908, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8058047493403694, 0.6428571428571429, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.8226912928759894, 0.7380952380952381, 'X[2] <= 0.59\ngini = 0.46\nsamples = 10\nvalue = [0, 0, 7, 1, 2, 0]'),
#  Text(0.8184696569920844, 0.6904761904761905, 'X[9] <= 0.995\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 7, 1, 0, 0]'),
#  Text(0.8142480211081794, 0.6428571428571429, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.8226912928759894, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8269129287598944, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8353562005277045, 0.7857142857142857, 'X[1] <= 1.147\ngini = 0.571\nsamples = 7\nvalue = [1, 4, 2, 0, 0, 0]'),
#  Text(0.8311345646437994, 0.7380952380952381, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0, 0]'),
#  Text(0.8395778364116095, 0.7380952380952381, 'X[9] <= 0.435\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 2, 0, 0, 0]'),
#  Text(0.8353562005277045, 0.6904761904761905, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.8437994722955146, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.9213720316622691, 0.8333333333333334, 'X[9] <= 0.705\ngini = 0.621\nsamples = 110\nvalue = [0, 3, 13, 58, 32, 4]'),
#  Text(0.8807387862796834, 0.7857142857142857, 'X[6] <= 15.5\ngini = 0.57\nsamples = 70\nvalue = [0, 3, 12, 43, 10, 2]'),
#  Text(0.8564643799472296, 0.7380952380952381, 'X[9] <= 0.525\ngini = 0.713\nsamples = 17\nvalue = [0, 1, 4, 4, 7, 1]'),
#  Text(0.8522427440633246, 0.6904761904761905, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.8606860158311346, 0.6904761904761905, 'X[10] <= 12.15\ngini = 0.653\nsamples = 14\nvalue = [0, 1, 1, 4, 7, 1]'),
#  Text(0.8480211081794196, 0.6428571428571429, 'X[0] <= 6.8\ngini = 0.449\nsamples = 7\nvalue = [0, 1, 0, 0, 5, 1]'),
#  Text(0.8437994722955146, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8522427440633246, 0.5952380952380952, 'X[4] <= 0.08\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 0, 5, 1]'),
#  Text(0.8480211081794196, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.8564643799472296, 0.5476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.8733509234828496, 0.6428571428571429, 'X[9] <= 0.625\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 1, 4, 2, 0]'),
#  Text(0.8691292875989446, 0.5952380952380952, 'X[8] <= 3.495\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.8649076517150396, 0.5476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.8733509234828496, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8775725593667546, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9050131926121372, 0.7380952380952381, 'X[8] <= 3.515\ngini = 0.431\nsamples = 53\nvalue = [0, 2, 8, 39, 3, 1]'),
#  Text(0.8944591029023746, 0.6904761904761905, 'X[3] <= 4.9\ngini = 0.266\nsamples = 34\nvalue = [0, 1, 2, 29, 1, 1]'),
#  Text(0.8902374670184696, 0.6428571428571429, 'X[6] <= 23.0\ngini = 0.222\nsamples = 33\nvalue = [0, 1, 2, 29, 1, 0]'),
#  Text(0.8860158311345646, 0.5952380952380952, 'X[1] <= 0.46\ngini = 0.485\nsamples = 13\nvalue = [0, 1, 2, 9, 1, 0]'),
#  Text(0.8817941952506596, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8902374670184696, 0.5476190476190477, 'X[6] <= 21.0\ngini = 0.403\nsamples = 12\nvalue = [0, 1, 2, 9, 0, 0]'),
#  Text(0.8860158311345646, 0.5, 'X[3] <= 3.025\ngini = 0.314\nsamples = 11\nvalue = [0, 1, 1, 9, 0, 0]'),
#  Text(0.8817941952506596, 0.4523809523809524, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.8902374670184696, 0.4523809523809524, 'X[4] <= 0.071\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 1, 2, 0, 0]'),
#  Text(0.8860158311345646, 0.40476190476190477, 'X[3] <= 4.025\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.8817941952506596, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8902374670184696, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8944591029023746, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8944591029023746, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8944591029023746, 0.5952380952380952, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 0, 20, 0, 0]'),
#  Text(0.8986807387862796, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9155672823218998, 0.6904761904761905, 'X[6] <= 27.5\ngini = 0.609\nsamples = 19\nvalue = [0, 1, 6, 10, 2, 0]'),
#  Text(0.9071240105540898, 0.6428571428571429, 'X[1] <= 0.727\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.9029023746701847, 0.5952380952380952, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.9113456464379948, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9240105540897098, 0.6428571428571429, 'X[8] <= 3.545\ngini = 0.485\nsamples = 13\nvalue = [0, 1, 1, 9, 2, 0]'),
#  Text(0.9197889182058048, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9282321899736148, 0.5952380952380952, 'X[10] <= 12.95\ngini = 0.314\nsamples = 11\nvalue = [0, 1, 1, 9, 0, 0]'),
#  Text(0.9240105540897098, 0.5476190476190477, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.9324538258575198, 0.5476190476190477, 'X[9] <= 0.595\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.9282321899736148, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9366754617414248, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9620052770448548, 0.7857142857142857, 'X[6] <= 22.5\ngini = 0.554\nsamples = 40\nvalue = [0, 0, 1, 15, 22, 2]'),
#  Text(0.9451187335092348, 0.7380952380952381, 'X[10] <= 11.55\ngini = 0.486\nsamples = 12\nvalue = [0, 0, 1, 8, 3, 0]'),
#  Text(0.9366754617414248, 0.6904761904761905, 'X[3] <= 4.075\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(0.9324538258575198, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9408970976253298, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9535620052770448, 0.6904761904761905, 'X[8] <= 3.015\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 0, 8, 1, 0]'),
#  Text(0.9493403693931398, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9577836411609498, 0.6428571428571429, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.978891820580475, 0.7380952380952381, 'X[5] <= 18.5\ngini = 0.472\nsamples = 28\nvalue = [0, 0, 0, 7, 19, 2]'),
#  Text(0.970448548812665, 0.6904761904761905, 'X[3] <= 1.55\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 0, 0, 11, 1]'),
#  Text(0.9662269129287598, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.97467018469657, 0.6428571428571429, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 0, 11, 0]'),
#  Text(0.987335092348285, 0.6904761904761905, 'X[3] <= 2.7\ngini = 0.555\nsamples = 16\nvalue = [0, 0, 0, 7, 8, 1]'),
#  Text(0.98311345646438, 0.6428571428571429, 'X[0] <= 9.1\ngini = 0.542\nsamples = 12\nvalue = [0, 0, 0, 7, 4, 1]'),
#  Text(0.97467018469657, 0.5952380952380952, 'X[5] <= 19.5\ngini = 0.406\nsamples = 8\nvalue = [0, 0, 0, 6, 1, 1]'),
#  Text(0.970448548812665, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.978891820580475, 0.5476190476190477, 'X[0] <= 6.65\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 6, 1, 0]'),
#  Text(0.97467018469657, 0.5, 'X[5] <= 31.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.970448548812665, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.978891820580475, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.98311345646438, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.99155672823219, 0.5952380952380952, 'X[5] <= 25.0\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 3, 0]'),
#  Text(0.987335092348285, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.995778364116095, 0.5476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.99155672823219, 0.6428571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]')]

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 0.4766146993318486

# %% [markdown]
# > Dummy model!
#
# It's an overfit model because training accuracy is very high and test accuracy is very low

# %% [markdown]
# # Hyperparameter Tuning

# %%
grid_param = {
    'criterion': ['gini', 'entropy'],
    'max_depth' : range(2,32,1),
    'min_samples_leaf': range(1,10,1),
    'min_samples_split': range(2,10,1),
    'splitter': ['best', 'random']
}

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(estimator=model, param_grid=grid_param, cv=5)

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 32),
#                          'min_samples_leaf': range(1, 10),
#                          'min_samples_split': range(2, 10),
#                          'splitter': ['best', 'random']})

# %%
grid_search.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 4,
#  'min_samples_leaf': 2,
#  'min_samples_split': 8,
#  'splitter': 'random'}

# %%
model_with_best_params = DecisionTreeClassifier(criterion='entropy',
                                                max_depth=4,
                                                min_samples_leaf=2,
                                                min_samples_split=8,
                                                splitter='random')

# %%
model_with_best_params.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_leaf=2,
#                        min_samples_split=8, splitter='random')

# %%
y_pred2 = model_with_best_params.predict(X_test)

# %%
accuracy_score(y_test, y_pred2)
# Out:
# 0.5812917594654788

# %% [markdown]
# # Our Accuracy improved!

# %% [markdown]
# # PLotting Tree

# %% [markdown]
# Controlling the depth of tree

# %%
from sklearn import tree
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(25,15))
tree.plot_tree(model_with_best_params, filled=True, fontsize=12)
# Out:
# [Text(0.5431034482758621, 0.9, 'X[10] <= 10.544\nentropy = 1.752\nsamples = 910\nvalue = [5, 38, 385, 354, 115, 13]'),
#  Text(0.27586206896551724, 0.7, 'X[1] <= 0.441\nentropy = 1.473\nsamples = 562\nvalue = [4, 26, 325, 179, 26, 2]'),
#  Text(0.13793103448275862, 0.5, 'X[10] <= 9.667\nentropy = 1.551\nsamples = 158\nvalue = [0, 2, 68, 69, 17, 2]'),
#  Text(0.06896551724137931, 0.3, 'X[0] <= 14.062\nentropy = 1.144\nsamples = 69\nvalue = [0, 1, 42, 25, 1, 0]'),
#  Text(0.034482758620689655, 0.1, 'entropy = 1.043\nsamples = 67\nvalue = [0, 1, 42, 24, 0, 0]'),
#  Text(0.10344827586206896, 0.1, 'entropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.20689655172413793, 0.3, 'X[2] <= 0.665\nentropy = 1.662\nsamples = 89\nvalue = [0, 1, 26, 44, 16, 2]'),
#  Text(0.1724137931034483, 0.1, 'entropy = 1.618\nsamples = 85\nvalue = [0, 1, 26, 42, 15, 1]'),
#  Text(0.2413793103448276, 0.1, 'entropy = 1.5\nsamples = 4\nvalue = [0, 0, 0, 2, 1, 1]'),
#  Text(0.41379310344827586, 0.5, 'X[6] <= 73.099\nentropy = 1.356\nsamples = 404\nvalue = [4, 24, 257, 110, 9, 0]'),
#  Text(0.3448275862068966, 0.3, 'X[10] <= 10.15\nentropy = 1.507\nsamples = 294\nvalue = [4, 23, 169, 89, 9, 0]'),
#  Text(0.3103448275862069, 0.1, 'entropy = 1.454\nsamples = 236\nvalue = [4, 21, 147, 59, 5, 0]'),
#  Text(0.3793103448275862, 0.1, 'entropy = 1.456\nsamples = 58\nvalue = [0, 2, 22, 30, 4, 0]'),
#  Text(0.4827586206896552, 0.3, 'X[9] <= 0.968\nentropy = 0.775\nsamples = 110\nvalue = [0, 1, 88, 21, 0, 0]'),
#  Text(0.4482758620689655, 0.1, 'entropy = 0.686\nsamples = 104\nvalue = [0, 0, 85, 19, 0, 0]'),
#  Text(0.5172413793103449, 0.1, 'entropy = 1.459\nsamples = 6\nvalue = [0, 1, 3, 2, 0, 0]'),
#  Text(0.8103448275862069, 0.7, 'X[9] <= 0.679\nentropy = 1.788\nsamples = 348\nvalue = [1, 12, 60, 175, 89, 11]'),
#  Text(0.6896551724137931, 0.5, 'X[8] <= 3.442\nentropy = 1.752\nsamples = 182\nvalue = [1, 12, 41, 98, 28, 2]'),
#  Text(0.6206896551724138, 0.3, 'X[2] <= 0.329\nentropy = 1.663\nsamples = 125\nvalue = [0, 5, 23, 70, 25, 2]'),
#  Text(0.5862068965517241, 0.1, 'entropy = 1.589\nsamples = 63\nvalue = [0, 5, 13, 37, 8, 0]'),
#  Text(0.6551724137931034, 0.1, 'entropy = 1.58\nsamples = 62\nvalue = [0, 0, 10, 33, 17, 2]'),
#  Text(0.7586206896551724, 0.3, 'X[1] <= 1.216\nentropy = 1.726\nsamples = 57\nvalue = [1, 7, 18, 28, 3, 0]'),
#  Text(0.7241379310344828, 0.1, 'entropy = 1.627\nsamples = 55\nvalue = [0, 7, 17, 28, 3, 0]'),
#  Text(0.7931034482758621, 0.1, 'entropy = 1.0\nsamples = 2\nvalue = [1, 0, 1, 0, 0, 0]'),
#  Text(0.9310344827586207, 0.5, 'X[2] <= 0.698\nentropy = 1.631\nsamples = 166\nvalue = [0, 0, 19, 77, 61, 9]'),
#  Text(0.896551724137931, 0.3, 'X[7] <= 0.994\nentropy = 1.635\nsamples = 161\nvalue = [0, 0, 19, 77, 56, 9]'),
#  Text(0.8620689655172413, 0.1, 'entropy = 1.287\nsamples = 14\nvalue = [0, 0, 0, 3, 9, 2]'),
#  Text(0.9310344827586207, 0.1, 'entropy = 1.615\nsamples = 147\nvalue = [0, 0, 19, 74, 47, 7]'),
#  Text(0.9655172413793104, 0.3, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]')]

# %%
fig.savefig("Decision_Tree_Classifier.png")

# %% [markdown]
# # Random Forest CLassifier

# %%
from sklearn.ensemble import RandomForestClassifier
Rf_model = RandomForestClassifier()

# %%
Rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf = Rf_model.predict(X_test)

# %%
accuracy_score(y_test, y_pred_rf)
# Out:
# 0.6325167037861915

# %% [markdown]
# ### Accuracy is more as compared to Decision Tree

# %%
grid_param_rf = {
    'n_estimators' : [90,100],
    'criterion': ['gini', 'entropy'],
    'max_depth': range(2,20,1),
    'min_samples_leaf': range(1,10,1),
    'min_samples_split': range(2,10,1),
    'max_features': ['auto', 'log2']
}

# %%
from sklearn.model_selection import GridSearchCV

grid_search_rf = GridSearchCV(estimator=Rf_model, param_grid=grid_param_rf, cv=3, verbose=2, n_jobs=-1)   # n_jobs shows the power it will use of system

# %%
grid_search_rf.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10368 candidates, totalling 31104 fits
# C:\Users\Himz\anaconda3\envs\EDA\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 20),
#                          'max_features': ['auto', 'log2'],
#                          'min_samples_leaf': range(1, 10),
#                          'min_samples_split': range(2, 10),
#                          'n_estimators': [90, 100]},
#              verbose=2)

# %%
grid_search_rf.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 13,
#  'max_features': 'auto',
#  'min_samples_leaf': 7,
#  'min_samples_split': 6,
#  'n_estimators': 90}

# %%
model_rf_better = RandomForestClassifier(criterion='gini', max_depth=13,
                                         max_features='auto', min_samples_leaf=7,
                                         min_samples_split=6, n_estimators=90)

# %%
model_rf_better.fit(X_train, y_train)
# Out:
# C:\Users\Himz\anaconda3\envs\EDA\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# RandomForestClassifier(max_depth=13, max_features='auto', min_samples_leaf=7,
#                        min_samples_split=6, n_estimators=90)

# %%
y_pred_rf_better = model_rf_better.predict(X_test)

# %%
accuracy_score(y_test, y_pred_rf_better)
# Out:
# 0.6525612472160356

# %% [markdown]
# ## Better Accuracy after Hyperparameter Tuning

# %% [markdown]
# > ## For ensembling we can use BaggingClassifier to ensemble various models

# %%
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier

modelbagging_svc = BaggingClassifier(
    base_estimator=SVC(),
    n_estimators=50,
    random_state=0
)

# %%
modelbagging_svc.fit(X_train, y_train)
y_pred_bag = modelbagging_svc.predict(X_test)

# %%
accuracy_score(y_test, y_pred_bag)
# Out:
# 0.5100222717149221

# %% [markdown]
# ### We got 51% Accuracy with SVC Ensembling

# %% [markdown]
# # In order to use multiple models for ensembling use VotingClassifier
